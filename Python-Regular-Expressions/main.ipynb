# %%
import re

sentence = 'Start a sentence and then bring it to an end'
text_to_search = '''
abcdefghijklmnopqurtuvwxyz
ABCDEFGHIJKLMNOPQRSTUVWXYZ
1234567890

Ha HaHa

MetaCharacters (Need to be escaped):
. ^ $ * + ? { } [ ] \ | ( )

coreyms.com

321-555-4321
123.555.1234
123*555*1234
800-555-1234
900-555-1234
800-555-1234
900-555-1234
900-555-1234


Mr. Schafer
Mr Smith
Ms Davis
Mrs. Robinson
Mr. T

cat
mat 
pat
bat
'''

# %% [markdown]
# '''
# abcdefghijklmnopqurtuvwxyz
# ABCDEFGHIJKLMNOPQRSTUVWXYZ
# 1234567890
#
# Ha HaHa
#
# MetaCharacters (Need to be escaped):
# . ^ $ * + ? { } [ ] \ | ( )
#
# coreyms.com
#
# 321-555-4321
# 123.555.1234
# 123*555*1234
# 800-555-1234
# 900-555-1234
#
# Mr. Schafer
# Mr Smith
# Ms Davis
# Mrs. Robinson
# Mr. T
# '''

# %%
#raw string -> strings prefix with r 
print('\tTab')
print(r'\tTab')
# Out:
# 	Tab
# \tTab

# %%
#pattern = re.compile(r'abc')
#pattern = re.compile(r'.')
#pattern = re.compile(r'\.') ##be careful of meta characters -> \ needed
#pattern = re.compile(r'\d')
#pattern = re.compile(r'\s')
#pattern = re.compile(r'\bHa')
#pattern = re.compile(r'\BHa')
#pattern = re.compile(r'^Meta')
#pattern = re.compile(r'm$')

#pattern = re.compile(r'\d\d\d.\d\d\d.\d\d\d\d')
#pattern = re.compile(r'\d\d\d[-.]\d\d\d[-.]\d\d\d\d') #matches using a dash or a dot -> use bracket to match a range of characters
    ###doesnt match 123--123-1234!
#pattern = re.compile(r'[89]00[-.]\d\d\d[-.]\d\d\d\d') 
#pattern = re.compile(r'[1-5]') 
#pattern = re.compile(r'[a-zA-Z]') 
#pattern = re.compile(r'[^a-zA-Z]')
#pattern = re.compile(r'[^b]at')
#pattern = re.compile(r'\d{3}.\d{3}.\d{4}') ##equals to pattern = re.compile(r'\d\d\d.\d\d\d.\d\d\d\d')

#pattern = re.compile(r'Mr\.?\s[A-Z]\w+')
#pattern = re.compile(r'Mr\.?\s[A-Z]\w*')
#pattern = re.compile(r'M(r|s|rs)\.?\s[A-Z]\w*') ##use () because it could search with pattern
pattern = re.compile(r'(Mr|Ms|Mrs)\.?\s[A-Z]\w*')

matches = pattern.finditer(text_to_search)

for match in matches:
    print(match)

#with open('/Users/natthanaphopisaradech/Documents/Data_Hub/code_snippets_Corey-Schafer/Python-Regular-Expressions/data.txt','r', encoding='utf-8') as f:
#    contents = f.read()
#    matches = pattern.finditer(contents)
#    for match in matches:
#        print(match)
# Out:
# <re.Match object; span=(261, 272), match='Mr. Schafer'>
# <re.Match object; span=(273, 281), match='Mr Smith'>
# <re.Match object; span=(282, 290), match='Ms Davis'>
# <re.Match object; span=(291, 304), match='Mrs. Robinson'>
# <re.Match object; span=(305, 310), match='Mr. T'>

# %% [markdown]
# Findall Method
# Return the matches as the list of strings

# %%
pattern = re.compile(r'\d{3}.\d{3}.\d{4}')

matches = pattern.findall(text_to_search)

for match in matches: 
    print(match)
# Out:
# 321-555-4321
# 123.555.1234
# 123*555*1234
# 800-555-1234
# 900-555-1234
# 800-555-1234
# 900-555-1234
# 900-555-1234

# %% [markdown]
# Match Method

# %%
pattern = re.compile(r'\d{3}.\d{3}.\d{4}')

matches = pattern.match(sentence)
print(matches)

pattern = re.compile(r'Start')

matches = pattern.match(sentence)
print(matches)
# Out:
# None
# <re.Match object; span=(0, 5), match='Start'>

# %% [markdown]
# Flag

# %%
#pattern = re.compile(r'Start')
pattern = re.compile(r'start', re.IGNORECASE)

matches = pattern.match(sentence)
print(matches)
# Out:
# <re.Match object; span=(0, 5), match='Start'>
